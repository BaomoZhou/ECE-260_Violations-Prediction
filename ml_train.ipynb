# %%
import pandas as pd
from scipy import stats 
from sklearn import linear_model
# to save model
import pickle

# %% [markdown]
# # Data extraction:

# %%
df = pd.read_csv("dataset/training.csv")
print(df.columns)
print(len(df))
# Out:
# Index(['netName_x', 'util', 'cp', 'bboxArea', 'bboxAr', 'numPins', 'numVias'], dtype='object')
# 34864

# %%
var = df[['bboxArea','bboxAr', 'numPins']]
label = df['numVias']

# %%
# Out:
#        bboxArea  bboxAr  numPins
# 0       967.303   0.191        7
# 1         1.600   0.400        4
# 2         0.000   0.000        2
# 3         0.000   0.000        2
# 4         0.000   0.000        2
# 5         0.000   0.000        2
# 6         0.000   0.000        2
# 7         0.000   0.000        2
# 8         0.000   0.000        2
# 9         0.000   0.000        2
# 10        0.000   0.000        2
# 11        0.000   0.000        2
# 12        0.000   0.000        2
# 13        0.000   0.000        2
# 14        0.000   0.000        2
# 15        0.000   0.000        2
# 16        0.000   0.000        2
# 17        0.000   0.000        2
# 18        0.000   0.000        2
# 19        0.000   0.000        2
# 20        0.000   0.000        2
# 21        0.000   0.000        2
# 22        0.000   0.000        2
# 23        0.000   0.000        2
# 24        0.000   0.000        2
# 25        0.000   0.000        2
# 26        0.000   0.000        2
# 27        0.000   0.000        2
# 28        0.000   0.000        2
# 29        0.000   0.000        2
# ...         ...     ...      ...
# 34834   367.200   1.133        9
# 34835   301.840   0.786       11
# 34836    44.800   0.357        4
# 34837    70.560   1.361        6
# 34838    39.600   1.100        5
# 34839   125.280   3.724       10
# 34840     4.000   0.250        2
# 34841     5.280   1.091        2
# 34842    88.320   1.043        8
# 34843    32.160   5.583        4
# 34844     0.720   0.500        2
# 34845   574.560   0.905       11
# 34846     0.160   1.000        2
# 34847   231.120   0.505        5
# 34848   629.920   1.024       11
# 34849    71.440   1.237        3
# 34850     4.000  25.000        3
# 34851     6.720   0.095        2
# 34852   158.360   2.892        6
# 34853     0.240   1.500        2
# 34854    53.360   0.630        5
# 34855     4.320   0.750        3
# 34856   159.600   4.433        5
# 34857   110.160   0.265        6
# 34858    24.000   4.167        5
# 34859   558.000   1.722       11
# 34860    51.840   1.000        4
# 34861    86.400   0.600        6
# 34862    12.760   0.379        5
# 34863    19.200   3.333        3
#
# [34864 rows x 3 columns]
